# %% [markdown]
# ## <font size=5> <strong>Heart Disease Prediction By Shreekant Gosavi

# %% [markdown]
# ## I. Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# ## II. Importing and understanding our dataset

# %%
dataset = pd.read_csv("heart.csv")

# %% [markdown]
# #### Verifying it as a 'dataframe' object in pandas

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Shape of dataset

# %%
dataset.shape
# Out:
# (303, 14)

# %% [markdown]
# #### Printing out a few columns

# %%
dataset.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
dataset.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 202   58    1   0       150   270    0        0      111      1      0.8
# 7     44    1   1       120   263    0        1      173      0      0.0
# 183   58    1   2       112   230    0        0      165      0      2.5
# 290   61    1   0       148   203    0        1      161      0      0.0
# 66    51    1   2       100   222    0        1      143      1      1.2
#
#      slope  ca  thal  target
# 202      2   0     3       0
# 7        2   0     3       1
# 183      1   1     3       0
# 290      2   1     3       0
# 66       1   0     2       1

# %% [markdown]
# #### Description

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
###Luckily, we have no missing values

# %% [markdown]
# #### Let's understand our columns better:

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(dataset.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# #### Analysing the 'target' variable

# %%
dataset["target"].describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# #### Clearly, this is a classification problem, with the target variable having values '0' and '1'

# %% [markdown]
# ### Checking correlation between columns

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %%
#This shows that most columns are moderately correlated with target, but 'fbs' is very weakly correlated.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### First, analysing the target variable:

# %%
y = dataset["target"]

sns.countplot(y)


target_temp = dataset.target.value_counts()

print(target_temp)
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/303,2)))

#Alternatively,
# print("Percentage of patience with heart problems: "+str(y.where(y==1).count()*100/303))
# print("Percentage of patience with heart problems: "+str(y.where(y==0).count()*100/303))

# #Or,
# countNoDisease = len(df[df.target == 0])
# countHaveDisease = len(df[df.target == 1])
# Out:
# Percentage of patience without heart problems: 45.54
# Percentage of patience with heart problems: 54.46

# %% [markdown]
# ### We'll analyse 'sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca' and 'thal' features

# %% [markdown]
# ### Analysing the 'Sex' feature

# %%
dataset["sex"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ##### We notice, that as expected, the 'sex' feature has 2 unique features

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
sns.barplot(dataset["sex"],y)

# %% [markdown]
# ##### We notice, that females are more likely to have heart problems than males

# %% [markdown]
# ### Analysing the 'Chest Pain Type' feature

# %%
dataset["cp"].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# ##### As expected, the CP feature has values from 0 to 3

# %%
sns.barplot(dataset["cp"],y)

# %% [markdown]
# ##### We notice, that chest pain of '0', i.e. the ones with typical angina are much less likely to have heart problems

# %% [markdown]
# ### Analysing the FBS feature

# %%
dataset["fbs"].describe()
# Out:
# count    303.000000
# mean       0.148515
# std        0.356198
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([1, 0])

# %%
sns.barplot(dataset["fbs"],y)

# %% [markdown]
# ##### Nothing extraordinary here

# %% [markdown]
# ### Analysing the restecg feature

# %%
dataset["restecg"].unique()
# Out:
# array([0, 1, 2])

# %%
sns.barplot(dataset["restecg"],y)

# %% [markdown]
# ##### We realize that people with restecg '1' and '0' are much more likely to have a heart disease than with restecg '2'

# %% [markdown]
# ### Analysing the 'exang' feature

# %%
dataset["exang"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(dataset["exang"],y)

# %% [markdown]
# ##### People with exang=1 i.e. Exercise induced angina are much less likely to have heart problems

# %% [markdown]
# ### Analysing the Slope feature

# %%
dataset["slope"].unique()
# Out:
# array([0, 2, 1])

# %%
sns.barplot(dataset["slope"],y)

# %% [markdown]
# ##### We observe, that Slope '2' causes heart pain much more than Slope '0' and '1'

# %% [markdown]
# ### Analysing the 'ca' feature

# %%
#number of major vessels (0-3) colored by flourosopy

# %%
dataset["ca"].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
sns.countplot(dataset["ca"])

# %%
sns.barplot(dataset["ca"],y)

# %% [markdown]
# ##### ca=4 has astonishingly large number of heart patients

# %%
### Analysing the 'thal' feature

# %%
dataset["thal"].unique()
# Out:
# array([1, 2, 3, 0])

# %%
sns.barplot(dataset["thal"],y)

# %%
sns.distplot(dataset["thal"])

# %% [markdown]
# ## IV. Train Test split

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
Y_train.shape
# Out:
# (242,)

# %%
Y_test.shape
# Out:
# (61,)

# %% [markdown]
# ## V. Model Fitting

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (61,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.25 %

# %% [markdown]
# ### SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (61,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.97 %

# %% [markdown]
# ### K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (61,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (61,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.97 %

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (61,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 90.16 %

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (61,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 85.25 %

# %% [markdown]
# ### Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# https://stats.stackexchange.com/a/136542 helped a lot in avoiding overfitting

model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 3ms/step - loss: 121.2377 - accuracy: 0.4587
# Epoch 2/300
# 8/8 [==============================] - 0s 3ms/step - loss: 113.7280 - accuracy: 0.4587
# Epoch 3/300
# 8/8 [==============================] - 0s 3ms/step - loss: 107.1674 - accuracy: 0.4587
# Epoch 4/300
# 8/8 [==============================] - 0s 3ms/step - loss: 100.0916 - accuracy: 0.4587
# Epoch 5/300
# 8/8 [==============================] - 0s 3ms/step - loss: 94.0104 - accuracy: 0.4587
# Epoch 6/300
# 8/8 [==============================] - 0s 3ms/step - loss: 87.8953 - accuracy: 0.4587
# Epoch 7/300
# 8/8 [==============================] - 0s 2ms/step - loss: 82.0268 - accuracy: 0.4587
# Epoch 8/300
# 8/8 [==============================] - 0s 3ms/step - loss: 76.5837 - accuracy: 0.4587
# Epoch 9/300
# 8/8 [==============================] - 0s 2ms/step - loss: 71.1845 - accuracy: 0.4587
# Epoch 10/300
# 8/8 [==============================] - 0s 3ms/step - loss: 66.2527 - accuracy: 0.4587
# Epoch 11/300
# 8/8 [==============================] - 0s 3ms/step - loss: 61.2490 - accuracy: 0.4587
# Epoch 12/300
# 8/8 [==============================] - 0s 3ms/step - loss: 56.5290 - accuracy: 0.4587
# Epoch 13/300
# 8/8 [==============================] - 0s 2ms/step - loss: 51.9919 - accuracy: 0.4587
# Epoch 14/300
# 8/8 [==============================] - 0s 2ms/step - loss: 47.6119 - accuracy: 0.4587
# Epoch 15/300
# 8/8 [==============================] - 0s 2ms/step - loss: 43.3888 - accuracy: 0.4587
# Epoch 16/300
# 8/8 [==============================] - 0s 2ms/step - loss: 39.2728 - accuracy: 0.4587
# Epoch 17/300
# 8/8 [==============================] - 0s 2ms/step - loss: 35.3510 - accuracy: 0.4587
# Epoch 18/300
# 8/8 [==============================] - 0s 3ms/step - loss: 31.5782 - accuracy: 0.4587
# Epoch 19/300
# 8/8 [==============================] - 0s 3ms/step - loss: 27.8579 - accuracy: 0.4587
# Epoch 20/300
# 8/8 [==============================] - 0s 3ms/step - loss: 24.3399 - accuracy: 0.4587
# Epoch 21/300
# 8/8 [==============================] - 0s 2ms/step - loss: 20.8942 - accuracy: 0.4587
# Epoch 22/300
# 8/8 [==============================] - 0s 2ms/step - loss: 17.5138 - accuracy: 0.4587
# Epoch 23/300
# 8/8 [==============================] - 0s 3ms/step - loss: 14.2352 - accuracy: 0.4587
# Epoch 24/300
# 8/8 [==============================] - 0s 3ms/step - loss: 10.5747 - accuracy: 0.4587
# Epoch 25/300
# 8/8 [==============================] - 0s 3ms/step - loss: 6.8899 - accuracy: 0.4545
# Epoch 26/300
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8080 - accuracy: 0.4174
# Epoch 27/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6350 - accuracy: 0.4628
# Epoch 28/300
# 8/8 [==============================] - 0s 3ms/step - loss: 2.7776 - accuracy: 0.5041
# Epoch 29/300
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5924 - accuracy: 0.5083
# Epoch 30/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3730 - accuracy: 0.4793
# Epoch 31/300
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3095 - accuracy: 0.4587
# Epoch 32/300
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2252 - accuracy: 0.4669
# Epoch 33/300
# 8/8 [==============================] - 0s 3ms/step - loss: 2.1332 - accuracy: 0.4711
# Epoch 34/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0550 - accuracy: 0.4876
# Epoch 35/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9817 - accuracy: 0.5000
# Epoch 36/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9133 - accuracy: 0.4959
# Epoch 37/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8437 - accuracy: 0.4959
# Epoch 38/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8015 - accuracy: 0.4959
# Epoch 39/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7533 - accuracy: 0.4917
# Epoch 40/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7251 - accuracy: 0.5000
# Epoch 41/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6758 - accuracy: 0.4959
# Epoch 42/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6371 - accuracy: 0.4876
# Epoch 43/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6003 - accuracy: 0.4959
# Epoch 44/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5695 - accuracy: 0.5000
# Epoch 45/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5381 - accuracy: 0.5000
# Epoch 46/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5131 - accuracy: 0.5041
# Epoch 47/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4844 - accuracy: 0.5041
# Epoch 48/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4584 - accuracy: 0.5041
# Epoch 49/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4333 - accuracy: 0.5083
# Epoch 50/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4099 - accuracy: 0.5041
# Epoch 51/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3840 - accuracy: 0.5083
# Epoch 52/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3621 - accuracy: 0.5248
# Epoch 53/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3372 - accuracy: 0.5248
# Epoch 54/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3101 - accuracy: 0.5331
# Epoch 55/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2872 - accuracy: 0.5289
# Epoch 56/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2589 - accuracy: 0.5248
# Epoch 57/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2313 - accuracy: 0.5455
# Epoch 58/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2054 - accuracy: 0.5496
# Epoch 59/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1785 - accuracy: 0.5455
# Epoch 60/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1448 - accuracy: 0.5537
# Epoch 61/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1209 - accuracy: 0.5496
# Epoch 62/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0859 - accuracy: 0.5620
# Epoch 63/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0619 - accuracy: 0.5744
# Epoch 64/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0328 - accuracy: 0.5785
# Epoch 65/300
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0032 - accuracy: 0.5661
# Epoch 66/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9768 - accuracy: 0.5661
# Epoch 67/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9506 - accuracy: 0.5702
# Epoch 68/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9262 - accuracy: 0.5744
# Epoch 69/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9110 - accuracy: 0.5785
# Epoch 70/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8787 - accuracy: 0.5868
# Epoch 71/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8627 - accuracy: 0.5785
# Epoch 72/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8298 - accuracy: 0.5702
# Epoch 73/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8112 - accuracy: 0.5744
# Epoch 74/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7938 - accuracy: 0.5744
# Epoch 75/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7712 - accuracy: 0.5868
# Epoch 76/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7571 - accuracy: 0.6033
# Epoch 77/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7354 - accuracy: 0.6074
# Epoch 78/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7299 - accuracy: 0.6281
# Epoch 79/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.
300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3869 - accuracy: 0.8347
# Epoch 204/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8347
# Epoch 205/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3810 - accuracy: 0.8471
# Epoch 206/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8512
# Epoch 207/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3798 - accuracy: 0.8512
# Epoch 208/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3825 - accuracy: 0.8554
# Epoch 209/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3861 - accuracy: 0.8388
# Epoch 210/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8554
# Epoch 211/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3818 - accuracy: 0.8471
# Epoch 212/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3846 - accuracy: 0.8347
# Epoch 213/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3794 - accuracy: 0.8512
# Epoch 214/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8554
# Epoch 215/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3771 - accuracy: 0.8554
# Epoch 216/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3801 - accuracy: 0.8554
# Epoch 217/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3822 - accuracy: 0.8347
# Epoch 218/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.8554
# Epoch 219/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3806 - accuracy: 0.8512
# Epoch 220/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8306
# Epoch 221/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.8554
# Epoch 222/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3810 - accuracy: 0.8512
# Epoch 223/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3774 - accuracy: 0.8430
# Epoch 224/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3764 - accuracy: 0.8595
# Epoch 225/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3758 - accuracy: 0.8512
# Epoch 226/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3764 - accuracy: 0.8430
# Epoch 227/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3792 - accuracy: 0.8512
# Epoch 228/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3721 - accuracy: 0.8636
# Epoch 229/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3819 - accuracy: 0.8347
# Epoch 230/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.8678
# Epoch 231/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3763 - accuracy: 0.8512
# Epoch 232/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8512
# Epoch 233/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3785 - accuracy: 0.8636
# Epoch 234/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3819 - accuracy: 0.8388
# Epoch 235/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8388
# Epoch 236/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.8554
# Epoch 237/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3705 - accuracy: 0.8595
# Epoch 238/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3785 - accuracy: 0.8264
# Epoch 239/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3750 - accuracy: 0.8636
# Epoch 240/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3796 - accuracy: 0.8388
# Epoch 241/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3706 - accuracy: 0.8636
# Epoch 242/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3784 - accuracy: 0.8430
# Epoch 243/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3710 - accuracy: 0.8471
# Epoch 244/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8554
# Epoch 245/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8678
# Epoch 246/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8430
# Epoch 247/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3714 - accuracy: 0.8595
# Epoch 248/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3707 - accuracy: 0.8471
# Epoch 249/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3706 - accuracy: 0.8512
# Epoch 250/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8471
# Epoch 251/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8512
# Epoch 252/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3709 - accuracy: 0.8430
# Epoch 253/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3727 - accuracy: 0.8388
# Epoch 254/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3803 - accuracy: 0.8264
# Epoch 255/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3674 - accuracy: 0.8512
# Epoch 256/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3843 - accuracy: 0.8264
# Epoch 257/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3726 - accuracy: 0.8430
# Epoch 258/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8264
# Epoch 259/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3724 - accuracy: 0.8388
# Epoch 260/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3789 - accuracy: 0.8223
# Epoch 261/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8264
# Epoch 262/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3878 - accuracy: 0.8306
# Epoch 263/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3745 - accuracy: 0.8636
# Epoch 264/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3722 - accuracy: 0.8388
# Epoch 265/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3651 - accuracy: 0.8678
# Epoch 266/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8595
# Epoch 267/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3748 - accuracy: 0.8347
# Epoch 268/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.8554
# Epoch 269/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8595
# Epoch 270/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8471
# Epoch 271/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8471
# Epoch 272/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3700 - accuracy: 0.8388
# Epoch 273/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8595
# Epoch 274/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3665 - accuracy: 0.8678
# Epoch 275/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3717 - accuracy: 0.8471
# Epoch 276/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3656 - accuracy: 0.8636
# Epoch 277/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3662 - accuracy: 0.8636
# Epoch 278/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3668 - accuracy: 0.8430
# Epoch 279/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3701 - accuracy: 0.8512
# Epoch 280/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8554
# Epoch 281/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3655 - accuracy: 0.8471
# Epoch 282/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8595
# Epoch 283/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.8388
# Epoch 284/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3642 - accuracy: 0.8512
# Epoch 285/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8678
# Epoch 286/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3649 - accuracy: 0.8678
# Epoch 287/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.8388
# Epoch 288/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3701 - accuracy: 0.8471
# Epoch 289/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3693 - accuracy: 0.8347
# Epoch 290/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8512
# Epoch 291/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8595
# Epoch 292/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3673 - accuracy: 0.8512
# Epoch 293/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3739 - accuracy: 0.8471
# Epoch 294/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.8347
# Epoch 295/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8264
# Epoch 296/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.8512
# Epoch 297/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3634 - accuracy: 0.8512
# Epoch 298/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8595
# Epoch 299/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8595
# Epoch 300/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3621 - accuracy: 0.8595

# %%
Y_pred_nn = model.predict(X_test)

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")

#Note: Accuracy of 85% can be achieved on the test set, by setting epochs=2000, and number of nodes = 11.
# Out:
# The accuracy score achieved using Neural Network is: 83.61 %

# %% [markdown]
# ## VI. Output final score

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %
# The accuracy score achieved using Naive Bayes is: 85.25 %
# The accuracy score achieved using Support Vector Machine is: 81.97 %
# The accuracy score achieved using K-Nearest Neighbors is: 67.21 %
# The accuracy score achieved using Decision Tree is: 81.97 %
# The accuracy score achieved using Random Forest is: 90.16 %
# The accuracy score achieved using XGBoost is: 85.25 %
# The accuracy score achieved using Neural Network is: 83.61 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

sns.barplot(algorithms,scores)

# %% [markdown]
# ### Hey arbaaz there random forest has good result as compare to other algorithms <br> <br>
